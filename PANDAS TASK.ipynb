# %% [markdown]
# **1.  explain the code to create a dataframe in pandas  using python list,python dictionary of tuples,python dictionary of list with example**

# %%
import pandas as pd
list1=['car','bike','bus','lorry']
ds=pd.DataFrame(list1)
ds=ds.drop(1)
ds
# Out:
#        0
# 0    car
# 2    bus
# 3  lorry

# %%
dict1={'Name':('Arun','Anu'),'Age':(25,28)}
ds=pd.DataFrame(dict1)
ds
# Out:
#    Name  Age
# 0  Arun   25
# 1   Anu   28

# %%
dict2={'Name':['Arun','Anu'],'Age':[25,28]}
ds=pd.DataFrame(dict2)
ds
# Out:
#    Name  Age
# 0  Arun   25
# 1   Anu   28

# %% [markdown]
# **2. Create a sample dataframe with shape 6x5  and write a program to get the first       3 rows of a given DataFrame**

# %%
data={'Name':['Chinju','Aju','Manju','Renju','Anju','Kunju',],'Age':[25,28,21,24,31,32],
      'Sex':['Female','Male','Female','Female','Female','Female'],'Address':['A','B','C','D','E','F'],
      'Status':['Studing','Working','Studing','Studing','Working','Studing']
     }
ds=pd.DataFrame(data,index=[1,2,3,4,5,6])
ds
# Out:
#      Name  Age     Sex Address   Status
# 1  Chinju   25  Female       A  Studing
# 2     Aju   28    Male       B  Working
# 3   Manju   21  Female       C  Studing
# 4   Renju   24  Female       D  Studing
# 5    Anju   31  Female       E  Working
# 6   Kunju   32  Female       F  Studing

# %%
ds.head(3)
# Out:
#      Name  Age     Sex Address   Status
# 1  Chinju   25  Female       A  Studing
# 2     Aju   28    Male       B  Working
# 3   Manju   21  Female       C  Studing

# %% [markdown]
# **3. Write a program to find the total number of columns in the below dataframe  and also find that is Micael qualified in the exam or not??
# exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
#  'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
#  'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#  'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}**

# %%
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew',
                      'Laura', 'Kevin', 'Jonas'],
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
ds=pd.DataFrame(exam_data,index= ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
ds
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
#number of columns

ds.shape[1]
# Out:
# 4

# %%
import numpy as np
idx = np.where((ds['name']=='Michael'))
idx
# Out:
# (array([5], dtype=int64),)

# %%
if (ds['qualify'][5])=='yes' :
    print("Qualified")
else:
    print("Not qualified")
# Out:
# Qualified

# %% [markdown]
# **4. How to read data from excel file and csv file in pandas explain with sample and mention how to skip unnecessary rows on the top of the data**

# %% [markdown]
# **Reading CSV File**

# %%
import pandas as pd
df=pd.read_csv('titanic (3).csv')
df
# Out:
#      PassengerId                                               Name  Pclass  \
# 0              1                            Braund, Mr. Owen Harris       3
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2              3                             Heikkinen, Miss. Laina       3
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4              5                           Allen, Mr. William Henry       3
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas       2
# 887          888                       Graham, Miss. Margaret Edith       1
# 888          889           Johnston, Miss. Catherine Helen "Carrie"       3
# 889          890                              Behr, Mr. Karl Howell       1
# 890          891                                Dooley, Mr. Patrick       3
#
# ...

# %% [markdown]
# **Reading Excel File**

# %%
import pandas as pd
df1=pd.read_excel(r"C:\Users\arunf\OneDrive\Documents\Data Science\EXCEL\data set\WUP2018-F13-Capital_Cities.xls")
df1
# Out:
#               Unnamed: 0                 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    NaN                        NaN        NaN        NaN
# 1                    NaN                        NaN        NaN        NaN
# 2                    NaN                        NaN        NaN        NaN
# 3         United Nations                        NaN        NaN        NaN
# 4    Population Division                        NaN        NaN        NaN
# ..                   ...                        ...        ...        ...
# 252                  237  Wallis and Futuna Islands        876   Matu-Utu
# 253                  238             Western Sahara        732   El Aaiún
# 254                  239                      Yemen        887    Sana'a'
# 255                  240                     Zambia        894     Lusaka
# 256                  241                   Zimbabwe        716     Harare
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %% [markdown]
# **5. Find the score of ‘d’**

# %%
ds
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
ds['score']['d']
# Out:
# nan

# %% [markdown]
# **6. Explain fillna(),dropna(),and interpolate(),replace() with code**

# %% [markdown]
# **fillna()  :**
# **used to fill null values with a specific value**

# %%
ds
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
filled=ds['score'].fillna(ds['score'].mean())

# %%
filled
# Out:
# a    12.5000
# b     9.0000
# c    16.5000
# d    13.5625
# e     9.0000
# f    20.0000
# g    14.5000
# h    13.5625
# i     8.0000
# j    19.0000
# Name: score, dtype: float64

# %% [markdown]
# **dropna() :**
# **used to remove rows with null value**

# %%
ds
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
dropped=ds.dropna()
dropped
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# **interpolate() :**
# **technique used to estimate the unknown data points between two known data points**

# %%
ds
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
inter=ds.interpolate()
inter
# Out:
#         name  score  attempts qualify
# a  Anastasia  12.50         1     yes
# b       Dima   9.00         3      no
# c  Katherine  16.50         2     yes
# d      James  12.75         3      no
# e      Emily   9.00         2      no
# f    Michael  20.00         3     yes
# g    Matthew  14.50         1     yes
# h      Laura  11.25         1      no
# i      Kevin   8.00         2      no
# j      Jonas  19.00         1     yes

# %% [markdown]
# **replace() :**

# %%
ds
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
ds['attempts'].replace(1,2)
# Out:
# a    2
# b    3
# c    2
# d    3
# e    2
# f    3
# g    2
# h    2
# i    2
# j    2
# Name: attempts, dtype: int64

# %% [markdown]
# **7. Explain concat with example**

# %% [markdown]
# **Concat gives the flexibility to join based on the axis( all rows or all columns)**

# %%
a=pd.Series(["Arun","Male"])
b=pd.Series(["Anu","Female"])
c=pd.concat([a,b],keys=['person 1 :','person 2 :'],names=['P.NO:', 'Row ID'])
c
# Out:
# P.NO:       Row ID
# person 1 :  0           Arun
#             1           Male
# person 2 :  0            Anu
#             1         Female
# dtype: object

# %% [markdown]
# **8. How to change the index to DateTimeIndex? Explain with weather data..**

# %%
import pandas as pd
import io

data = """value          
"2015-09-25 00:46"    71.925000
"2015-09-25 00:47"    71.625000
"2015-09-25 00:48"    71.333333
"2015-09-25 00:49"    64.571429
"2015-09-25 00:50"    72.285714"""

df = pd.read_table(io.StringIO(data), delim_whitespace=True)

# Converting the index as date
df.index = pd.to_datetime(df.index)

# Extracting hour & minute
df['A'] = df.index.hour
df['B'] = df.index.minute
df
# Out:
#                          value  A   B
# 2015-09-25 00:46:00  71.925000  0  46
# 2015-09-25 00:47:00  71.625000  0  47
# 2015-09-25 00:48:00  71.333333  0  48
# 2015-09-25 00:49:00  64.571429  0  49
# 2015-09-25 00:50:00  72.285714  0  50

# %% [markdown]
# **9. What is merge in pandas explain all types of merges with drivers data**

# %% [markdown]
# **10. Get the movie_data.csv and do all exercises.**

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\arunf\Downloads\movie_data.csv\movie_data.csv")

# %%
data
# Out:
#                                                   review  sentiment
# 0      In 1974, the teenager Martha Moxley (Maggie Gr...          1
# 1      OK... so... I really like Kris Kristofferson a...          0
# 2      ***SPOILER*** Do not read this, if you think a...          0
# 3      hi for all the people who have seen this wonde...          1
# 4      I recently bought the DVD, forgetting just how...          0
# ...                                                  ...        ...
# 49995  OK, lets start with the best. the building. al...          0
# 49996  The British 'heritage film' industry is out of...          0
# 49997  I don't even know where to begin on this one. ...          0
# 49998  Richard Tyler is a little boy who is scared of...          0
# 49999  I waited long to watch this movie. Also becaus...          1
#
# [50000 rows x 2 columns]

# %% [markdown]
# **Write a Python Pandas program to get the columns of the DataFrame (movies_metadata.csv file)?**

# %%
for col in data.columns:
    print(col)
# Out:
# review
# sentiment

# %% [markdown]
# **Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'**

# %% [markdown]
# **Write a Pandas program to display the first 10 rows of the DataFrame**

# %% [markdown]
# **Write a Pandas program to sort the DataFrame based on release_date**

# %% [markdown]
# **Write a Pandas program to access those movies, released after 1995-01-01**

# %% [markdown]
# **Write a Pandas program to get those movies whose revenue more than 2 million and
# spent less than 1 million.**

# %% [markdown]
# **Write a Pandas program to get the longest runtime and shortest runtime**

# %% [markdown]
# **Find the total number of movie released in november 1995 and its total revenue
# list all movies that belongs to action and romance genre?**
